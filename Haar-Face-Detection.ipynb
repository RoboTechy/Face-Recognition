# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 align="center">Face Detection using Haar Cascades classifiers</h1>
#     <h2 align="center"><a href="mirch.cs@gmail.com">M.Shahi</a></h3>
# </div>

# %% [markdown]
# ## OpenCV provides pre-trained Haar cascades for face detection, which can be used as a simple face recognition method.

# %% [markdown]
# ## Topics:
#
# - [ ] import necessary libraries
# - [ ] Load the pre-trained Haar Cascade classifier
# - [ ] Read the input image
# - [ ] Detect faces
# - [ ] Draw rectangles around the faces
# - [ ] Display the output

# %% [markdown]
# # import necessary libraries

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the pre-trained Haar Cascade classifier

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %% [markdown]
# # Read the input image

# %%
image = cv2.imread('Personal.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# # Detect faces

# %%
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.2, minNeighbors=5, minSize=(100, 100))

# %% [markdown]
# # Draw rectangles around the faces

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (255, 0, 0), 2)

# %% [markdown]
# # Display the output

# %%
plt.imshow(image[:,:,::-1])
